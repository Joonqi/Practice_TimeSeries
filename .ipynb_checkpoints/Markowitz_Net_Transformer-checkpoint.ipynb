# %% [markdown]
# # Markowitz Network using Transformer

# %%
import pandas_datareader as pdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, GlobalAveragePooling1D, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import tensorflow_probability as tfp

# %% [markdown]
# ## 데이터 준비
# 다우존스 지수를 활용
# 2000년 이후 최신 데이터까지 포함, 해당 기간 중 데이터가 모두 존재하는 27개 기업 선별
# 앞 4000개의 데이터 (~ 2015년 11월) 로 훈련
# 이후 데이터를 통해 검증

# %%
tickers = pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')
symbols = tickers[1]['Symbol'].reset_index(drop=True).sort_values()
return_d = pdr.yahoo.daily.YahooDailyReader(symbols, start='JAN-01-2000')
df = return_d.read()['Adj Close']
return_d.close()

df = df.dropna(axis=1).pct_change()
df = df.dropna()
column = df.columns

# %%
df_train = df.iloc[:4000]
df_test = df.iloc[4000:]

# %%
df
# Out:
# Symbols         AAPL      AMGN       AXP        BA       CAT      CSCO  \
# Date
# 2000-01-03  0.088754  0.047867 -0.054135 -0.030166  0.033200  0.008751
# 2000-01-04 -0.084310 -0.076465 -0.037758 -0.001555 -0.012854 -0.056102
# 2000-01-05  0.014633  0.034409 -0.025399  0.062305  0.023437 -0.003064
# 2000-01-06 -0.086538  0.016632  0.020374  0.010264  0.050890 -0.016595
# 2000-01-07  0.047369  0.112474  0.014559  0.029027  0.032688  0.058750
# ...              ...       ...       ...       ...       ...       ...
# 2022-01-24 -0.004864 -0.007202  0.001197 -0.006036  0.001121  0.003881
# 2022-01-25 -0.011385 -0.004600  0.089222 -0.000490 -0.000093 -0.013884
# 2022-01-26 -0.000563 -0.011109  0.012766 -0.048163 -0.000093 -0.013901
# 2022-01-27 -0.002943  0.006561 -0.019507 -0.023267 -0.009893 -0.012832
# 2022-01-28  0.069778  0.022946  0.030017  0.004322 -0.051892  0.018125
#
# Symbols          CVX       DIS        GS        HD  ...       MMM       MRK  \
# Date                                                ...
# 2000-01-03 -0.034632  0.021367 -0.062376 -0.051818  ... -0.035760  0.006512
# 2000-01-04  0.000000  0.058577 -0.062986 -0.052733  ... -0.039735 -0.035120
# 2000-01-05  0.017938  0.041502 -0.046828  0.020243  ...  0.028966  0.039271
# 2000-01-06  0.042584 -0.039848  0.042789 -0.047619  ...  0.080429  0.008295
# 2000-01-07  0.017606 -0.015810  0.003800  0.058333  ...  0.019851  0.095978
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-01-24  0.002127  0.000582 -0.001512  0.042137  ...  0.000869 -0.014379
# 2022-01-25  0.042538 -0.006911 -0.005358 -0.013276  ...  0.005498  0.007992
# 2022-01-26  0.000754 -0.021317  0.003308 -0.004736  ... -0.025611 -0.004027
# 2022-01-27  0.020197  0.013623 -0.004815 -0.002379  ...  0.005080  0.018196
# 2022-01-28 -0.035163  0.023704  0.017535  0.028365  ... -0.041490  0.003971
#
# Symbols         MSFT       NKE        PG       TRV       UNH        VZ  \
# Date
# 2000-01-03 -0.001606 -0.029004 -0.021677 -0.020408  0.011765 -0.026396
# 2000-01-04 -0.033779 -0.054545 -0.019242 -0.013257 -0.012790 -0.032325
# 2000-01-05  0.010544  0.057692 -0.019025 -0.007678 -0.002356  0.033405
# 2000-01-06 -0.033498 -0.005195  0.046060  0.019343  0.036600 -0.005079
# 2000-01-07  0.013068  0.000000  0.079953  0.039848  0.117312 -0.007384
# ...              ...       ...       ...       ...       ...       ...
# 2022-01-24  0.001149  0.021336 -0.008117  0.038251  0.002385 -0.003762
# 2022-01-25 -0.026588 -0.003562 -0.010911 -0.001362 -0.011746 -0.001133
# 2022-01-26  0.028493 -0.010242 -0.008713 -0.004389  0.003480 -0.035539
# 2022-01-27  0.010549  0.004514  0.006197 -0.013106  0.006915  0.003332
# 2022-01-28  0.028082  0.008780  0.008609  0.007002  0.009662  0.033405
#
# Symbols          WBA       WMT
# Date
# 2000-01-03 -0.023504 -0.033453
# 2000-01-04 -0.037199 -0.037419
# 2000-01-05  0.011364 -0.020408
# 2000-01-06 -0.029213  0.010912
# 2000-01-07  0.025463  0.075565
# ...              ...       ...
# 2022-01-24 -0.002286  0.000071
# 2022-01-25 -0.026537 -0.021755
# 2022-01-26 -0.024122 -0.010208
# 2022-01-27  0.004823  0.000663
# 2022-01-28  0.009200  0.012368
#
# [5555 rows x 27 columns]

# %%
N_time = 60
N_future = 20
N_stock = 27
BATCH = 64

# %%
xc_train = np.zeros((4000-N_time-N_future, N_time, N_stock), np.float32)
xf_train = np.zeros((4000-N_time-N_future, N_future, N_stock), np.float32)

for i in range(N_time, 4000-N_future):
    xc_train[i-N_time] = df_train.iloc[i-N_time:i]
    xf_train[i-N_time] = df_train.iloc[i+1:i+1+N_future]
print(xc_train.shape)
# Out:
# (3920, 60, 27)

# %%
xc_test = np.zeros((len(df_test)-N_time-N_future, N_time, N_stock), np.float32)
xf_test = np.zeros((len(df_test)-N_time-N_future, N_future, N_stock), np.float32)

for i in range(N_time, len(df_test)-N_future):
    xc_test[i-N_time] = df_test.iloc[i-N_time:i]
    xf_test[i-N_time] = df_test.iloc[i+1:i+1+N_future]
print(xc_test.shape)
# Out:
# (1475, 60, 27)

# %%
xc_train = xc_train
xf_train = xf_train
xc_test = xc_test
xf_test = xf_test

GAMMA_CONST = 0.1
REG_CONST = 0.1
SAVE_MODEL = 'data/2-2.Markowitz_network_attn.h5'

# %% [markdown]
# ## Markowitz Portfolio Theory
# https://en.wikipedia.org/wiki/Modern_portfolio_theory

# %%
def markowitz_objective(y_true, y_pred):
    W = y_pred
    xf_rtn = y_true
    W = tf.expand_dims(W, axis=1)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis=1), axis=2)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)
    
    rtn = tf.matmul(W, R)
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm=[0, 2, 1])))*GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis=-1)*REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_mean(objective, axis=0)

# %% [markdown]
# #### Define Attention layer
# https://www.tensorflow.org/text/tutorials/transformer

# %%
def scaled_dot_product_attention(q, k, v, mask):
    '''
    q : query shape == (None, seq_len_q, depth)
    k : key shape == (None, seq_len_k, depth)
    v : value shape == (None, seq_len_v, depth_v)
    
    '''
    matmul_qk = tf.matmul(q, k, transpose_b = True)
    # scale matmul_qk
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk/tf.math.sqrt(dk)
    # add mask
    if mask is not None:
        scaled_attention_logits += (mask * -1e9)
    #softmax is normalized
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)
    output = tf.matmul(attention_weights, v)
    
    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        
        assert d_model % self.num_heads == 0
        self.depth = d_model // self.num_heads
        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)
        
        self.dense = tf.keras.layers.Dense(d_model)
        
    def split_heads(self, x, batch_size):
        '''
        split the last dimension into (num_heads, depth)
        transpose the result into (batch_size, num_heads, seq_len, depth)
        '''
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])
    
    def call(self, v, k, q, mask):
        batch_size=tf.shape(q)[0]
        
        q = self.wq(q)  # (batch_size, seq_len, d_model)
        k = self.wk(k)
        v = self.wv(v)
        
        q = self.split_heads(q, batch_size)   # (batch_size, num_heads, seq_len_q, depth)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)
        
        scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v, mask)
        
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        
        output = self.dense(concat_attention)
        return output, attention_weights

# %%
# check
temp_mha = MultiHeadAttention(d_model=512, num_heads=8)
y = tf.random.uniform((1, 60, 512)) # (batch_size, encoder_sequence, d_model)
out, attn = temp_mha(y, k=y, q=y, mask=None)
print(out.shape, attn.shape)
# Out:
# (1, 60, 512) (1, 8, 60, 60)

# %%
def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),
        tf.keras.layers.Dense(d_model)
    ])
sample_ffn = point_wise_feed_forward_network(512, 2048)
sample_ffn(tf.random.uniform((64, 50, 512))).shape
# Out:
# TensorShape([64, 50, 512])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1, **kwargs):
        super(EncoderLayer, self).__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.dff = dff
        self.rate = rate
        
        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)
        
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        
    def call(self, x, training, mask=False):
        attn_output, _ = self.mha(x, x, x, mask)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)
        
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)
        
        return out2
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "d_model": self.d_model,
            "num_heads": self.d_model,
            "dff": self.dff,
            "rate": self.rate
        })
        return config

# %%
# check
sample_encoder_layer = EncoderLayer(512, 8, 2048)
sample_encoder_layer_output = sample_encoder_layer(
    tf.random.uniform((64, 43, 512)), False, None)
sample_encoder_layer_output.shape
# Out:
# TensorShape([64, 43, 512])

# %%
xc_input = Input(batch_shape = (None, N_time, N_stock))
enc_output = EncoderLayer(d_model=N_stock, num_heads=3, dff=128, rate=0.3)(xc_input)
y_output = GlobalAveragePooling1D()(enc_output)
y_output = Activation('tanh')(y_output)

y_output = Activation('softmax')(y_output)

model = Model(xc_input, y_output)
model.compile(loss=markowitz_objective, optimizer=Adam(learning_rate=1e-5))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 60, 27)]          0
#
#  encoder_layer_1 (EncoderLay  (None, 60, 27)           10199
#  er)
#
#  global_average_pooling1d (G  (None, 27)               0
#  lobalAveragePooling1D)
#
#  activation (Activation)     (None, 27)                0
#
#  activation_1 (Activation)   (None, 27)                0
#
# =================================================================
# Total params: 10,199
# Trainable params: 10,199
# Non-trainable params: 0
# _________________________________________________________________

# %%
times = 20
hist = model.fit(xc_train*times, xf_train*times, epochs=150, batch_size=BATCH,
                validation_data=(xc_test*times, xf_test*times))
config = model.get_config()
model.save(SAVE_MODEL)
# Out:
# Epoch 1/150
# 62/62 [==============================] - 3s 21ms/step - loss: 1.5392e-04 - val_loss: -0.0047
# Epoch 2/150
# 62/62 [==============================] - 1s 9ms/step - loss: 9.1218e-05 - val_loss: -0.0048
# Epoch 3/150
# 62/62 [==============================] - 1s 9ms/step - loss: 6.3760e-06 - val_loss: -0.0048
# Epoch 4/150
# 62/62 [==============================] - 1s 9ms/step - loss: -4.7636e-05 - val_loss: -0.0048
# Epoch 5/150
# 62/62 [==============================] - 1s 10ms/step - loss: -1.1458e-04 - val_loss: -0.0048
# Epoch 6/150
# 62/62 [==============================] - 1s 9ms/step - loss: -1.8965e-04 - val_loss: -0.0049
# Epoch 7/150
# 62/62 [==============================] - 1s 9ms/step - loss: -2.6214e-04 - val_loss: -0.0049
# Epoch 8/150
# 62/62 [==============================] - 1s 9ms/step - loss: -3.0451e-04 - val_loss: -0.0049
# Epoch 9/150
# 62/62 [==============================] - 1s 9ms/step - loss: -3.7452e-04 - val_loss: -0.0049
# Epoch 10/150
# 62/62 [==============================] - 1s 9ms/step - loss: -4.2857e-04 - val_loss: -0.0049
# Epoch 11/150
# 62/62 [==============================] - 1s 9ms/step - loss: -4.9584e-04 - val_loss: -0.0050
# Epoch 12/150
# 62/62 [==============================] - 1s 9ms/step - loss: -5.7089e-04 - val_loss: -0.0050
# Epoch 13/150
# 62/62 [==============================] - 1s 9ms/step - loss: -6.1714e-04 - val_loss: -0.0050
# Epoch 14/150
# 62/62 [==============================] - 1s 10ms/step - loss: -6.6509e-04 - val_loss: -0.0050
# Epoch 15/150
# 62/62 [==============================] - 1s 9ms/step - loss: -7.1217e-04 - val_loss: -0.0050
# Epoch 16/150
# 62/62 [==============================] - 1s 9ms/step - loss: -7.7396e-04 - val_loss: -0.0051
# Epoch 17/150
# 62/62 [==============================] - 1s 9ms/step - loss: -8.2805e-04 - val_loss: -0.0051
# Epoch 18/150
# 62/62 [==============================] - 1s 9ms/step - loss: -8.7727e-04 - val_loss: -0.0051
# Epoch 19/150
# 62/62 [==============================] - 1s 9ms/step - loss: -9.3216e-04 - val_loss: -0.0051
# Epoch 20/150
# 62/62 [==============================] - 1s 9ms/step - loss: -9.5703e-04 - val_loss: -0.0051
# Epoch 21/150
# 62/62 [==============================] - 1s 10ms/step - loss: -9.9940e-04 - val_loss: -0.0051
# Epoch 22/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0010 - val_loss: -0.0051
# Epoch 23/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0011 - val_loss: -0.0051
# Epoch 24/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0011 - val_loss: -0.0052
# Epoch 25/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0012 - val_loss: -0.0052
# Epoch 26/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0012 - val_loss: -0.0052
# Epoch 27/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0012 - val_loss: -0.0052
# Epoch 28/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0013 - val_loss: -0.0052
# Epoch 29/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0013 - val_loss: -0.0052
# Epoch 30/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0013 - val_loss: -0.0052
# Epoch 31/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0014 - val_loss: -0.0052
# Epoch 32/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0014 - val_loss: -0.0052
# Epoch 33/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0014 - val_loss: -0.0052
# Epoch 34/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0015 - val_loss: -0.0052
# Epoch 35/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0015 - val_loss: -0.0052
# Epoch 36/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0015 - val_loss: -0.0052
# Epoch 37/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0015 - val_loss: -0.0052
# Epoch 38/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0016 - val_loss: -0.0052
# Epoch 39/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0016 - val_loss: -0.0052
# Epoch 40/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0016 - val_loss: -0.0053
# Epoch 41/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0016 - val_loss: -0.0053
# Epoch 42/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0017 - val_loss: -0.0053
# Epoch 43/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0017 - val_loss: -0.0053
# Epoch 44/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0017 - val_loss: -0.0053
# Epoch 45/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0017 - val_loss: -0.0053
# Epoch 46/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0018 - val_loss: -0.0053
# Epoch 47/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0018 - val_loss: -0.0053
# Epoch 48/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0018 - val_loss: -0.0053
# Epoch 49/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0018 - val_loss: -0.0053
# Epoch 50/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0018 - val_loss: -0.0053
# Epoch 51/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0018 - val_loss: -0.0053
# Epoch 52/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0019 - val_loss: -0.0053
# Epoch 53/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0019 - val_loss: -0.0053
# Epoch 54/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0019 - val_loss: -0.0053
# Epoch 55/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0019 - val_loss: -0.0053
# Epoch 56/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0019 - val_loss: -0.0053
# Epoch 57/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0020 - val_loss: -0.0053
# Epoch 58/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0020 - val_loss: -0.0053
# Epoch 59/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0020 - val_loss: -0.0053
# Epoch 60/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0020 - val_loss: -0.0053
# Epoch 61/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0020 - val_loss: -0.0053
# Epoch 62/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0020 - val_loss: -0.0053
# Epoch 63/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0020 - val_loss: -0.0053
# Epoch 64/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0021 - val_loss: -0.0053
# Epoch 65/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0021 - val_loss: -0.0053
# Epoch 66/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0021 - val_loss: -0.0053
# Epoch 67/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0021 - val_loss: -0.0053
# Epoch 68/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0021 - val_loss: -0.0053
# Epoch 69/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0021 - val_loss: -0.0053
# Epoch 70/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0021 - val_loss: -0.0053
# Epoch 71/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0022 - val_loss: -0.0053
# Epoch 72/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0022 - val_loss: -0.0053
# Epoch 73/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0022 - val_loss: -0.0053
# Epoch 74/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0022 - val_loss: -0.0053
# Epoch 75/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0022 - val_loss: -0.0053
# Epoch 76/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0022 - val_loss: -0.0053
# Epoch 77/150
# 62/62 [==============================] - 1s 11ms/step - loss: -0.0022 - val_loss: -0.0053
# Epoch 78/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0023 - val_loss: -0.0053
# Epoch 79/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0023 - val_loss: -0.0053
# Epoch 80/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0023 - val_loss: -0.0053
# Epoch 81/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0023 - val_loss: -0.0053
# Epoch 82/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0023 - val_loss: -0.0053
# Epoch 83/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0023 - val_loss: -0.0053
# Epoch 84/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0023 - val_loss: -0.0053
# Epoch 85/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0023 - val_loss: -0.0053
# Epoch 86/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0024 - val_loss: -0.0053
# Epoch 87/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0024 - val_loss: -0.0053
# Epoch 88/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0024 - val_loss: -0.0053
# Epoch 89/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0024 - val_loss: -0.0053
# Epoch 90/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0024 - val_loss: -0.0053
# Epoch 91/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0024 - val_loss: -0.0053
# Epoch 92/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0024 - val_loss: -0.0053
# Epoch 93/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0024 - val_loss: -0.0053
# Epoch 94/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 95/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 96/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 97/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 98/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 99/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 100/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 101/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 102/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0025 - val_loss: -0.0053
# Epoch 103/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0026 - val_loss: -0.0053
# Epoch 104/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0026 - val_loss: -0.0053
# Epoch 105/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0026 - val_loss: -0.0053
# Epoch 106/150
# 62/62 [==============================] - 1s 10ms/step - loss: -0.0026 - val_loss: -0.0053
# Epoch 107/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0026 - val_loss: -0.0053
# Epoch 108/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0026 - val_loss: -0.0053
# Epoch 109/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0027 - val_loss: -0.0053
# Epoch 110/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0026 - val_loss: -0.0053
# Epoch 111/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0027 - val_loss: -0.0053
# Epoch 112/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0027 - val_loss: -0.0053
# Epoch 113/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0027 - val_loss: -0.0053
# Epoch 114/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0027 - val_loss: -0.0053
# Epoch 115/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0027 - val_loss: -0.0053
# Epoch 116/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0027 - val_loss: -0.0053
# Epoch 117/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0027 - val_loss: -0.0053
# Epoch 118/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0028 - val_loss: -0.0053
# Epoch 119/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0028 - val_loss: -0.0053
# Epoch 120/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0028 - val_loss: -0.0053
# Epoch 121/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0028 - val_loss: -0.0053
# Epoch 122/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0028 - val_loss: -0.0053
# Epoch 123/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0028 - val_loss: -0.0053
# Epoch 124/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0028 - val_loss: -0.0053
# Epoch 125/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0028 - val_loss: -0.0053
# Epoch 126/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0029 - val_loss: -0.0053
# Epoch 127/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0029 - val_loss: -0.0053
# Epoch 128/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0029 - val_loss: -0.0053
# Epoch 129/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0029 - val_loss: -0.0053
# Epoch 130/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0029 - val_loss: -0.0053
# Epoch 131/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0029 - val_loss: -0.0053
# Epoch 132/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0029 - val_loss: -0.0053
# Epoch 133/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0029 - val_loss: -0.0053
# Epoch 134/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0030 - val_loss: -0.0053
# Epoch 135/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0030 - val_loss: -0.0053
# Epoch 136/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0030 - val_loss: -0.0053
# Epoch 137/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0030 - val_loss: -0.0053
# Epoch 138/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0030 - val_loss: -0.0053
# Epoch 139/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0030 - val_loss: -0.0053
# Epoch 140/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0030 - val_loss: -0.0053
# Epoch 141/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0030 - val_loss: -0.0053
# Epoch 142/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053
# Epoch 143/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053
# Epoch 144/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053
# Epoch 145/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053
# Epoch 146/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053
# Epoch 147/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053
# Epoch 148/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053
# Epoch 149/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053
# Epoch 150/150
# 62/62 [==============================] - 1s 9ms/step - loss: -0.0031 - val_loss: -0.0053

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.plot(hist.history['loss'], label='Train Loss')
plt.plot(hist.history['val_loss'], label='Test Loss')
plt.legend()
plt.show()

# %%
def check_w(n=0):
    plt.figure(figsize=(15,4))
    y_pred = model.predict(xc_test[n].reshape(1, N_time, N_stock))[0]
    plt.bar(column, y_pred*100, alpha=.7)
    plt.show()
check_w(0)
# Out:
# 1/1 [==============================] - 0s 375ms/step

# %%
model = tf.keras.models.load_model(
    SAVE_MODEL, custom_objects={'EncoderLayer':EncoderLayer}, compile=False
)
model.compile(loss=markowitz_objective, optimizer=Adam(learning_rate=1e-5))

mpn_value = [10000]
crp_value = [10000]
w_crp = np.ones(N_stock)/N_stock

w_hist = []
for i in range(N_future, xc_test.shape[0], N_future):
    x = xc_test[i][np.newaxis, :, :] * 20.0
    w_prt = model.predict(x)[0]
    w_hist.append(w_prt)
    
    m_rtn = np.sum(xf_test[i], axis=0)
    
    mpn_value.append(mpn_value[-1] * np.exp(np.dot(w_prt, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))
# Out:
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step

# %%
test_date = []
for i in range(0, xc_test.shape[0], N_future):
    test_date.append(df_test.index[i])
print(len(test_date))
# Out:
# 74

# %%
idx = np.arange(0, len(xc_test), N_future)

perf_df = pd.DataFrame({'crp':crp_value, 'markowitz':mpn_value},
                       index=df_test.index[idx])

# %%
perf_df
# Out:
#                      crp     markowitz
# Date
# 2015-11-25  10000.000000  10000.000000
# 2015-12-24  10245.186877  10203.483105
# 2016-01-26   9921.120259   9861.219860
# 2016-02-24  10135.505184  10076.076128
# 2016-03-23  10663.689401  10592.038816
# ...                  ...           ...
# 2021-05-21  26329.296454  27735.692821
# 2021-06-21  25919.148900  27188.542775
# 2021-07-20  27118.119422  28534.116041
# 2021-08-17  26955.519429  28657.462383
# 2021-09-15  28100.137910  29662.648752
#
# [74 rows x 2 columns]

# %%
round((perf_df.markowitz/perf_df.crp)[-1], 4)*100
# Out:
# 105.56

# %%
plt.figure(figsize=(10, 6))
plt.plot(perf_df['crp'], 'o-', label='CRP_Return')
plt.plot(perf_df['markowitz'], 'o-', label='MPN_Return')
plt.legend()
plt.show()

# %%
model = tf.keras.models.load_model(
    SAVE_MODEL, custom_objects={'EncoderLayer':EncoderLayer}, compile=False
)
model.compile(loss=markowitz_objective, optimizer=Adam(learning_rate=1e-5))

mpn_value = [10000]
crp_value = [10000]
w_crp = np.ones(N_stock)/N_stock

w_hist = []
for i in range(N_future, xc_test.shape[0], N_future):
    x = xc_test[i][np.newaxis, :, :] * 20.0
    w_prt = model.predict(x)[0]
    w_hist.append(w_prt)
    
    m_rtn = np.sum(xf_test[i], axis=0)
    
    mpn_value.append(mpn_value[-1] * np.exp(np.dot(w_prt, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))
    
    # 추가학습 진행
    # xc_test[0] ~ xc_test[19],
    # xf_test[0] ~ xf_test[19]를 추가로 학습시킬 수 있다.
    xc_new = xc_test[i:(i+N_future), :, :]
    xf_new = xf_test[i:(i+N_future), :, :]
    
    # xc_train 데이터에서 80개를 random sample
    idx = np.random.randint(0, xc_train.shape[0], 80)
    x = np.vstack([xc_new, xc_train[idx]])
    y = np.vstack([xf_new, xf_train[idx]])

    x *= 20.0
    y *= 20.0
    model.fit(x, y, epochs=50, batch_size=16, verbose=0)
    xc_train = np.vstack([xc_train, xc_new])
    xf_train = np.vstack([xf_train, xf_new])
# Out:
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
test_date = []
for i in range(0, xc_test.shape[0], N_future):
    test_date.append(df_test.index[i])
print(len(test_date))
# Out:
# 74

# %%
idx = np.arange(0, len(xc_test), N_future)

perf_df = pd.DataFrame({'crp':crp_value, 'markowitz':mpn_value},
                       index=df_test.index[idx])

# %%
round((perf_df.markowitz[-1]/perf_df.crp[-1]), 4)*100
# Out:
# 120.44999999999999

# %%
plt.figure(figsize=(10, 6))
plt.plot(perf_df['crp'], 'o-', label='CRP_Return')
plt.plot(perf_df['markowitz'], 'o-', label='MPN_Return')
plt.legend()
plt.show()
